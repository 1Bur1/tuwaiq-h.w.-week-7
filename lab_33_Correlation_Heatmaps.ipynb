# %%
"""
Day 33 Activity: Correlation Heatmaps
Tasks:
1) Compute correlation matrix
2) Plot heatmap with annotations
"""

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load data from data/day33_corr.csv
df = pd.read_csv("day33_corr.csv")

# TODO: Compute df.corr() and plot heatmap
corr_matrix = df.corr()
print(corr_matrix)

plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.show()
# Out:
#           feat_a    feat_b    feat_c    target
# feat_a  1.000000  1.000000 -0.992278  0.998700
# feat_b  1.000000  1.000000 -0.992278  0.998700
# feat_c -0.992278 -0.992278  1.000000 -0.993569
# target  0.998700  0.998700 -0.993569  1.000000
